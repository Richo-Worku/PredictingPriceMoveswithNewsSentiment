# %%
import os
import matplotlib.pyplot as plt

from scripts.technical_indicators import analyze_stock

# %%
stocks = {}
import os

folder_path = "Data/"
for file in os.listdir(folder_path):

    if file.endswith(".csv"):

        stock_name = file.replace(".csv", "")

        file_path = os.path.join(folder_path, file)
        stocks[stock_name] = analyze_stock(file_path)
        for stock in stocks:
         df = stocks["AAPL"]
       
df["close"].rolling(10).mean().head(15)
# Out:
# date
# 2009-01-02         NaN
# 2009-01-05         NaN
# 2009-01-06         NaN
# 2009-01-07         NaN
# 2009-01-08         NaN
# 2009-01-09         NaN
# 2009-01-12         NaN
# 2009-01-13         NaN
# 2009-01-14         NaN
# 2009-01-15    2.692356
# 2009-01-16    2.667103
# 2009-01-20    2.617978
# 2009-01-21    2.587417
# 2009-01-22    2.579469
# 2009-01-23    2.566453
# Name: close, dtype: float64

# %%
stocks = {}
import os

folder_path = "Data/"
for file in os.listdir(folder_path):

    if file.endswith(".csv"):

        stock_name = file.replace(".csv", "")

        file_path = os.path.join(folder_path, file)

        stocks[stock_name] = analyze_stock(file_path)
     

print("All stocks processed successfully!")
import matplotlib.pyplot as plt

df = stocks["AAPL"]
df.isnull().sum()
df["sma_10"].head(20)
df_clean = df.dropna()
plt.figure(figsize=(14,6))

plt.plot(df.index, df["close"], label="Close Price")

plt.plot(df.index, df["sma_20"], label="SMA 20")

# plt.plot(df.index, df["ema_20"], label="EMA 20")
# plt.plot(df.index, df["macd"] , label="MACD")
# plt.plot(df.index,df["macd_signal"] , label="MACD SIGNAL")

plt.title("AAPL closing prices overlaid with moving averages")

plt.xlabel("Date")

plt.ylabel("Price")

plt.legend()

plt.figure(figsize=(14,6))

plt.plot(df.index,  df["rsi"] , label="RSI")


# plt.plot(df.index, df["ema_20"], label="EMA 20")
# plt.plot(df.index, df["macd"] , label="MACD")
# plt.plot(df.index,df["macd_signal"] , label="MACD SIGNAL")



plt.title("AAPL RSI")

plt.xlabel("Date")

plt.ylabel("Price")

plt.legend()

plt.show()
# Out:
# All stocks processed successfully!
